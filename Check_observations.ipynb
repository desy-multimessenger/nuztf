# %%
from ztfquery import query
import numpy as np
import datetime

# %%
def get_ztf_data(date=None):
    """Function to grab data for a given date using ztfquery. 
    Date should be given in format YYYYMMDD, with the day being the UT day for the END of the night.
    By default, today is selected
    """
    if date is None:
        print("No date specified. Assuming today.")
        now = datetime.datetime.now()
        date = now.strftime("%Y%m%d")
    print("Date is", date)
    return query.NightSummary(date)

# %%
full_data = get_ztf_data()

print("Most recent observation in database was at:", full_data.data.iloc[-1]["UT_START"], "(UT)")
# Out:
# No date specified. Assuming today.
# Date is 20190710
# Most recent observation in database was at: 2019-07-10T11:42:45.1 (UT)

# %%
print("There are the following possible qcomments:", set(full_data.data.qcomment))
# Out:
# There are the following possible qcomments: {'reference_building_i', 'nightly_plane', 'reference_building_g_1_Ca', 'all_sky', 'i_band', 'high_cadence', 'reference_building_r_1_Ca', 'reference_building_r_1', 'Partnership_Plane_Summer2', 'reference_building_r_0', 'reference_building_g_1', 'Caltech_Plane_Summer2019', 'ToO_GRB190708B', 'reference_building_g_0'}

# %%
print("The observations you want are labelled ToO")
mask = np.array(["ToO" in x for x in full_data.data.qcomment])
print("There are", np.sum(mask), "ToO observations")
if np.sum(mask) == 0:
    print("No ToO observations found. Are you sure you have waited long enough?")
# Out:
# The observations you want are labelled ToO
# There are 10 ToO observations

# %%
too_data = full_data.data[mask]
print("Summary of ToO observations:")
print(too_data)
# Out:
# Summary of ToO observations:
#                   UT_START  sun  exp fid  type field pid        ra     dec  \
# 381  2019-07-10T08:33:09.0  -34   30   2  targ   493   3  323.1738  4.5500
# 382  2019-07-10T08:33:47.9  -34   30   2  targ   493   3  323.1738  4.5500
# 383  2019-07-10T08:34:27.0  -34   30   2  targ   493   3  323.1738  4.5500
# 384  2019-07-10T08:35:06.2  -33  120   2  targ   493   3  323.1738  4.5500
# 385  2019-07-10T08:37:15.5  -33  120   2  targ   494   3  330.1847  4.5500
# 554  2019-07-10T10:33:07.5  -23   30   2  targ   493   3  323.1738  4.5500
# 555  2019-07-10T10:33:46.5  -22   30   2  targ   493   3  323.1738  4.5500
# 556  2019-07-10T10:34:25.5  -22   30   2  targ   493   3  323.1738  4.5500
# 557  2019-07-10T10:35:04.8  -22  120   2  targ   493   3  323.1738  4.5500
# 558  2019-07-10T10:37:13.7  -22  120   2  targ   494   3  330.1847  4.5500
#
#       slew   wait                      fileroot progpi        qcomment
# 381   0.00    8.9  ztf_20190710356065_000493_zr     Ho  ToO_GRB190708B
# 382   0.00    9.1  ztf_20190710356782_000493_zr     Ho  ToO_GRB190708B
# 383   0.00    9.2  ztf_20190710357234_000493_zr     Ho  ToO_GRB190708B
# 384   6.99    9.3  ztf_20190710357697_000493_zr     Ho  ToO_GRB190708B
# 385  22.15   13.0  ztf_20190710359190_000494_zr     Ho  ToO_GRB190708B
# 554   0.00    9.0  ztf_20190710439387_000493_zr     Ho  ToO_GRB190708B
# 555   0.00    9.1  ztf_20190710440104_000493_zr     Ho  ToO_GRB190708B
# 556   0.00    9.2  ztf_20190710440556_000493_zr     Ho  ToO_GRB190708B
# 557   6.99    9.0  ztf_20190710441007_000493_zr     Ho  ToO_GRB190708B
# 558  37.83  106.4  ztf_20190710442500_000494_zr     Ho  ToO_GRB190708B

# %%
print(full_data.data)
# Out:
#                   UT_START  sun exp fid  type field pid        ra       dec  \
# 0    2019-07-10T04:03:15.4  -12  30   3  targ   481   2  240.1425    4.5500
# 1    2019-07-10T04:03:59.4  -12  30   3  targ   631   2  233.3994   26.1500
# 2    2019-07-10T04:04:38.3  -12  30   3  targ   583   2  238.0418   18.9500
# 3    2019-07-10T04:05:19.9  -12  30   3  targ   482   2  246.9842    4.5500
# 4    2019-07-10T04:06:04.1  -12  30   3  targ   632   2  240.8811   26.1500
# 5    2019-07-10T04:06:43.9  -13  30   3  targ   633   2  248.3629   26.1500
# 6    2019-07-10T04:07:26.3  -13  30   3  targ   678   2  235.4431   33.3500
# 7    2019-07-10T04:08:06.0  -13  30   3  targ   679   2  243.2964   33.3500
# 8    2019-07-10T04:08:45.8  -13  30   3  targ   680   2  251.1496   33.3500
# 9    2019-07-10T04:09:35.4  -13  30   3  targ   684   2  282.5628   33.3500
# 10   2019-07-10T04:10:14.4  -13  30   3  targ   726   2  278.4182   40.5500
# 11   2019-07-10T04:10:53.2  -13  30   3  targ   765   2  282.9221   47.7500
# 12   2019-07-10T04:11:32.1  -13  30   3  targ   798   2  279.9935   54.9500
# 13   2019-07-10T04:12:20.3  -14  30   3  targ   723   2  252.5677   40.5500
# 14   2019-07-10T04:13:00.4  -14  30   3  targ   722   2  243.9509   40.5500
# 15   2019-07-10T04:13:41.1  -14  30   3  targ   762   2  253.5980   47.7500
# 16   2019-07-10T04:14:20.2  -14  30   3  targ   796   2  257.7985   54.9500
# 17   2019-07-10T04:15:01.7  -14  30   3  targ   824   2  246.6667   62.1500
# 18   2019-07-10T04:15:40.6  -14  30   3  targ   795   2  246.7010   54.9500
# 19   2019-07-10T04:16:19.5  -14  30   3  targ   761   2  243.8233   47.7500
# 20   2019-07-10T04:16:59.6  -14  30   3  targ   721   2  235.3341   40.5500
# 21   2019-07-10T04:17:38.7  -14  30   3  targ   760   2  234.0486   47.7500
# 22   2019-07-10T04:18:17.7  -14  30   3  targ   794   2  235.6036   54.9500
# 23   2019-07-10T04:18:56.7  -15  30   3  targ   823   2  233.3333   62.1500
# 24   2019-07-10T04:19:35.7  -15  30   3  targ   846   2  231.4286   69.3500
# 25   2019-07-10T04:20:17.4  -15  30   3  targ   793   2  224.5061   54.9500
# 26   2019-07-10T04:20:56.5  -15  30   3  targ   759   2  224.2739   47.7500
# 624   7.60   8.9  ztf_20190710476840_000695_zr  Kulkarni
# 625   7.20   9.3  ztf_20190710477292_000649_zr  Kulkarni
# 626  21.56  16.5  ztf_20190710477743_000601_zr  Kulkarni
# 627  20.52  17.5  ztf_20190710478194_000692_zr  Kulkarni
# 628   7.21   8.9  ztf_20190710478738_000550_zr  Kulkarni
# 629  40.26  23.3  ztf_20190710479282_000499_zr  Kulkarni
# 630   6.77   9.3  ztf_20190710479734_000341_zr  Kulkarni
# 631  51.48  23.7  ztf_20190710480347_000340_zr  Kulkarni
# 632   6.50   9.8  ztf_20190710480799_000691_zr  Kulkarni
# 633  36.85  24.6  ztf_20190710481424_000692_zr  Kulkarni
# 634  18.11  13.5  ztf_20190710481887_000775_zr  Kulkarni
# 635  32.10  24.6  ztf_20190710482512_000695_zr  Kulkarni
# 636  23.13  14.7  ztf_20190710483021_000700_zr  Kulkarni
# 637  18.31  12.7  ztf_20190710483657_000556_zr  Kulkarni
# 638   7.99   9.1  ztf_20190710484167_000451_zr  Kulkarni
# 639  19.93  13.2  ztf_20190710484664_000400_zr  Kulkarni
# 640  12.56  11.1  ztf_20190710485116_000296_zr  Kulkarni
# 641   7.99   9.3  ztf_20190710485613_000345_zr  Kulkarni
# 642   6.77   9.2  ztf_20190710486088_000294_zr  Kulkarni
# 643  32.40  17.7  ztf_20190710486551_000344_zr  Kulkarni
# 644   0.00   9.1  ztf_20190710487002_001595_zr  Kulkarni
# 645   3.61   8.8  ztf_20190710487558_001595_zr  Kulkarni
# 646  -1.00  -1.0  ztf_20190710488009_000549_zr  Kulkarni
#
#                       qcomment
# 0                       i_band
# 1                       i_band
# 2                       i_band
# 3                       i_band
# 4                       i_band
# 5                       i_band
# 6                       i_band
# 7                       i_band
# 8                       i_band
# 9                       i_band
# 10                      i_band
# 11                      i_band
# 12                      i_band
# 13                      i_band
# 14                      i_band
# 15                      i_band
# 16                      i_band
# 17                      i_band
# 18                      i_band
# 19                      i_band
# 20                      i_band
# 21                      i_band
# 22                      i_band
# 23                      i_band
# 24                      i_band
# 25                      i_band
# 26                      i_band
# 27                      i_band
# 28                      i_band
# 29                      i_band
# ..                         ...
# 617                    all_sky
# 618               high_cadence
# 619              nightly_plane
# 620              nightly_plane
# 621              nightly_plane
# 622                    all_sky
# 623                    all_sky
# 624                    all_sky
# 625                    all_sky
# 626                    all_sky
# 627                    all_sky
# 628                    all_sky
# 629                    all_sky
# 630                    all_sky
# 631                    all_sky
# 632               high_cadence
# 633               high_cadence
# 634              nightly_plane
# 635               high_cadence
# 636                    all_sky
# 637                    all_sky
# 638                    all_sky
# 639                    all_sky
# 640                    all_sky
# 641                    all_sky
# 642                    all_sky
# 643                    all_sky
# 644     reference_building_r_1
# 645  reference_building_r_1_Ca
# 646     reference_building_r_0
#
# [647 rows x 14 columns]
