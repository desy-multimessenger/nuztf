# %%
# %matplotlib inline
from ztfquery import lightcurve

# %%
def plot_position(ra, dec, rad):
    lcq = lightcurve.LCQuery()
    lcq = lcq.query_position(ra, dec, rad)
    lcq.show_lc()

# %%
plot_position(346.181678, +12.202749, 5.)
